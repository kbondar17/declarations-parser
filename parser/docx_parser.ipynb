# %%
# %matplotlib inline
import requests
import re
import time
import os
import urllib.request
from typing import Union
import csv
import statistics
import pdf2docx

import pickle

import camelot
import typing
import io
import numpy as np
from docx import Document
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
# %config Completer.use_jedi = False
from pathlib import Path
# import tqdm.notebook.tqdm as tqdm
from tqdm import tqdm_notebook
# %matplotlib widget
import matplotlib.pyplot as plt
import logging
logging.basicConfig(format=u'%(filename)+13s [ LINE:%(lineno)-4s] %(levelname)-8s %(message)s',
                    level=logging.DEBUG)

logger = logging.getLogger(__name__)

from docx2python import docx2python
import traceback
import io

# %%
try:
    raise ValueError('aa')
except:

# %%
buffer.seek(0)
a = buffer.readlines()
a
# Out:
# ['Traceback (most recent call last):\n',
#  '  File "C:\\Users\\Kirill\\AppData\\Local\\Temp/ipykernel_23064/1851564243.py", line 5, in <module>\n',
#  "    raise ValueError('aa')\n",
#  'ValueError: aa\n']

# %%
class DataCleaner:

    @staticmethod
    def drop_same_cols(df: pd.DataFrame)->pd.DataFrame:
        to_remove = []
        for row in df.itertuples():    
            index = row[0]
            row = list(row)[1:]
            if len(set(row))<2:
                to_remove.append(index)
        df = df.drop(index=to_remove)
        return df

# %%
class HeaderFinder:

    def find_and_split_departments(self, df: pd.DataFrame) -> pd.DataFrame: # отдает df с департаментом, если он был в таблице 

                    
        def _add_department_info_to_df(df: pd.DataFrame, dep_info: list[dict[int, str]]) -> pd.DataFrame:
            df['department'] = None
            for data in dep_info: 
                df.at[data['index'], 'department'] = data['dep']       
            df = df.dropna(axis=1, how='all').fillna(method='ffill', axis=0)
            return df


        # table splitter
        def _find_department_in_table(df: pd.DataFrame) -> list[dict[int, str]]: # [index, department]
            departments_n_indexes = []
            for row in df.itertuples():
                index = row[0]
                row = list(row)[1:-1]
                row = [e for e in row if len(str(e)) > 4]
                if len(set(row))<2:
                    if not all([type(e) in [int, float] for e in row]):  
                        if statistics.mean([len(e) for e in row]) > 4:
                            departments_n_indexes.append({'index':index, 'dep': row[0]})
            return departments_n_indexes

        dep_info = _find_department_in_table(df)
        
        if not dep_info:
            return df
        
        # добавили колонку с департаментом    
        df = _add_department_info_to_df(df, dep_info)
        # удалили одинаковые ряды
        # df = ''
        return df



header_finder = HeaderFinder()
data_cleaner = DataCleaner()

r = header_finder.find_and_split_departments(df)
# data_cleaner.drop_same_cols(r)

# indx = _find_department_in_table(df)
# indx
# df

# %%
class DocxParser:

    def get_docx_tables(self, filename, tab_id=None, **kwargs) -> list[pd.DataFrame]:
        """
            filename:   file name of a Word Document
            tab_id:     parse a single table with the index: [tab_id] (counting from 0).
                        When [None] - return a list of DataFrames (parse all tables)
        """
        def read_docx_tab(tab, **kwargs):
            vf = io.StringIO()
            writer = csv.writer(vf)
            for row in tab.rows:
                writer.writerow(cell.text for cell in row.cells)
            vf.seek(0)
            return pd.read_csv(vf, **kwargs)

        doc = Document(filename)
        if tab_id is None:
            return [read_docx_tab(tab, **kwargs) for tab in doc.tables]
        else:
            try:
                return read_docx_tab(doc.tables[tab_id], **kwargs)
            except IndexError:
                print('Error: specified [tab_id]: {}  does not exist.'.format(tab_id))
                raise
            

    def convert_docx_to_df(self, filename: str) -> pd.DataFrame:
        assert filename.endswith('docx'), 'Формат должен быть .docx!'
            
        doc = Document(filename)
        # TODO: тут взять текст, который потом прикрутить к

        doc_tables = self.get_docx_tables(filename) 
        
        return doc_tables


    @staticmethod
    def find_ok_cols(cols: tuple) -> Union[dict[int, str], None]: # отдает словарь с колонками, которые надо переименовать
        '''ищем заголовки в таблице'''
        
        cols = list(map(str, cols))[:-1]
        cols = list(map(str.lower, cols))
        if len(set(cols)) == 1:
            return 

        ok_cols = 0
        result = {} # 'n_of_col':'new_name'
        for i, col in enumerate(cols):
            if len(result) > 5 or i > 20:
                return result

            if re.search(pattern='(фамилия|имя|фио|ф\.и\.о\.|ф\.и\.о|отчество)', string=col) and 'name' not in result.values():
                result[i] = 'name'
                ok_cols+=1

            elif re.search(pattern='(рублей|руб|cреднемесячная|зарпл.|плат[ы, е, а]|заработн[ой, ая] плат[а, ы]|cреднемесячн[ая, ой]|зарплат[а, ной, ы])', string=col): #and "salary" not in result.values():
                result[i] = "salary"
                ok_cols+=1
                
            elif re.search(pattern='(должност[ь, и, ей])', string=col) and 'position' not in result.values(): 
                result[i] = 'position'
                ok_cols+=1
                
            elif re.search(pattern='(предприяти[е,я]|учреждени[е,я]|юридическ|организаци|наименование [оу, мо])', string=col) and 'department' not in result.values():
                result[i] = 'department'
                ok_cols+=1

        if len(result) >= 2:
            return result
        return False


    def detect_headers(self, df: pd.DataFrame)-> dict[bool, pd.DataFrame]: # словарь с результатом найденных заголовков
        # сместили колонки в ряды        
        df.loc[-1] = df.columns  # adding a row
        df.index = df.index + 1  # shifting index
        df = df.sort_index()  # sorting by index

        for row in df.itertuples():
            index = row[0] 
            new_cols = self.find_ok_cols(row[1:])
            if new_cols:
                break

        if not new_cols:
            return {'ok_cols':False, 'df':df}

        df = df.iloc[index+1:,:]
         
        return {'ok_cols':True, 'df':df}


    def concatenate_if_possible(self, dfs: list[dict['df':pd.DataFrame, 'ok_cols':bool]]) -> list[pd.DataFrame]:

        all_oks = [e['ok_cols'] for e in dfs]

        if all(all_oks):
            return [e['df'] for e in dfs]

        result_df = []
        df_to_concat = pd.DataFrame()
        for df_info in dfs:
            if df_info['ok_cols']:
                if not df_to_concat.empty:
                    result_df.append(df_to_concat)
                df_to_concat = df_info['df']

            # оставляем только таблицы, у которых совпадает число колонок
            # с df у которых мы колонки нашли
            # если не нашли колонки и не к чему присоединять - дропаем

            elif not df_info['ok_cols'] and not df_to_concat.empty \
                    and len(df_to_concat.columns) == len(df_info['df'].columns):
                df_info['df'].columns = df_to_concat.columns
                df_to_concat = pd.concat([df_to_concat, df_info['df']])

        result_df.append(df_to_concat)

        return result_df

    @staticmethod
    def rename_df_col(df: pd.DataFrame) -> pd.DataFrame:
        cols = df.columns
        cols = list(map(str.lower, cols))

        for i,col in enumerate(cols):
            if re.search(pattern='(фамилия|имя|фио|ф\.и\.о\.|ф\.и\.о|отчество)', string=col):
                cols[i] = "name"

            elif re.search(pattern='(рублей|руб|cреднемесячная|зарпл.|плат[ы, а]|заработн[ой, ая] плат[а, ы]|cреднемесячн[ая, ой]|зарплат[а, ной, ы])', string=col):
                cols[i] = "salary"

            elif re.search(pattern='(должност[ь, и, ей])', string=col):
                cols[i] = 'position'

            elif re.search(pattern='(предприяти[е,я]|учреждени[е,я]|юридическ|организаци)', string=col):
                cols[i] = 'department'
        
        df.columns = cols
        return df
    
    @staticmethod
    def get_offices_from_doc(filename:str) -> list[str]:

        doc = docx2python(filename)

        table_pattern = '(фамилия|имя|фио|ф\.и\.о\.|ф\.и\.о|отчество|должность)'

        offices = []
        gathering_office_info = ''

        for paragraph in doc.body_runs:  # параграфы в виде вложенных листов

            paragraph = sum(sum(paragraph, []), [])
            paragraph_text = ''
            for e in paragraph:
                try:
                    paragraph_text += ' ' + e[0] + ' '
                except IndexError:
                    pass

            paragraph_text = paragraph_text.lower()
            its_table = re.findall(
                pattern=table_pattern, string=paragraph_text)

            if not its_table:
                gathering_office_info += paragraph_text

            elif its_table:
                offices.append(gathering_office_info)
                gathering_office_info = ''

        return [e for e in offices if e]

    @staticmethod
    def compile_office_info_and_df(departments: list, tables: list[pd.DataFrame]) -> typing.Union[None, list[pd.DataFrame]]:

        ok_dfs = []

        print('Количество заголовков --- ', len(departments))
        print('Количество таблиц --- ', len(tables))

        if len(departments) - len(tables) == 1:
            departments.pop()

        if len(departments) == len(tables):
            for table, dep in zip(tables, departments):
                table['department'] = dep
                table['department'][0] = 'Учреждение'
                ok_dfs.append(table)

            return ok_dfs

        raise ValueError(
            f'Разное число таблиц ({len(tables)}) и учреждений ({len(departments)})')


    def parse_file(self, filepath:str):
        dfs = self.get_docx_tables(filepath)
        dfs = [self.detect_headers(df) for df in dfs]
        dfs = self.concatenate_if_possible(dfs)
        dfs = [self.rename_df_col(df) for df in dfs]
        
        how_many_dfs_with_departments = sum([1 for e in dfs if 'department' in e.columns])
        # если учреждений больше, чем у половины таблиц, то отдаем так
        if how_many_dfs_with_departments > len(dfs) // 2 :
            return dfs

        else:

            dfs = [header_finder.find_and_split_departments(df) for df in dfs]

            how_many_dfs_with_departments = sum([1 for e in dfs if 'department' in e.columns])
            # если учреждений больше, чем у половины таблиц, то отдаем так
            if how_many_dfs_with_departments > len(dfs) // 2 :
                return dfs

            departments = self.get_offices_from_doc(filepath)
            dfs = self.compile_office_info_and_df(tables=dfs, departments=departments)
            return dfs




# file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\docx\83299_2018_Rukovoditeli,_zamestiteli_i_glavnye_bukhgaltery_podvedomstvennykh_uchrezhdenii.docx"
# file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\docx\83310_2016_Rukovoditeli,_zamestiteli_i_glavnye_bukhgaltery_podvedomstvennykh_uchrezhdenii.docx"
# #file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\docx\83292_2016_Rukovoditeli,_zamestiteli_i_glavnye_bukhgaltery_podvedomstvennykh_uchrezhdenii.docx"
# file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\docx\83316_2018_Rukovoditeli,_zamestiteli_i_glavnye_bukhgaltery_podvedomstvennykh_uchrezhdenii.docx"
file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\all_docx\83310_2016_Rukovoditeli,_zamestiteli_i_glavnye_bukhgaltery_podvedomstvennykh_uchrezhdenii.docx"
file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\all_docx\83349_2018_Rukovoditeli,_zamestiteli_i_glavnye_bukhgaltery_podvedomstvennykh_uchrezhdenii_(ne_ukazany_FIO).docx"
file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\all_docx\83364_2018_Rukovoditeli,_zamestiteli_i_glavnye_bukhgaltery_podvedomstvennykh_uchrezhdenii.docx"
# file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\all_docx\188073_2020_Rukovoditeli_podvedomstvennykh_uchrezhdenii_(obrazovanie).docx"
# file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\all_docx\aaa.docx"
# file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\all_docx\187331_2020_Rukovoditeli_podvedomstvennykh_uchrezhdenii.docx"

parser = DocxParser()

res = parser.parse_file(file)
res
# Out:
# [                                                № п/п  \
#  1                                                   1
#  2   1. Департамент по недропользованию по Централь...
#  3                                                  1.
#  4                                                  2.
#  5                                                  3.
#  ..                                                ...
#  64  10. Управление по недропользованию по Республи...
#  65                                                 1.
#  66                                                 2.
#  67                                                 3.
#  68                                                 4.
#
#                                                   name  \
#  1                                                   2
#  2   1. Департамент по недропользованию по Централь...
#  3                                       Савицкий М.Ф.
#  4                                         Гурина К.М.
#  5                                         Лексин Н.Н.
#  ..                                                ...
#  64  10. Управление по недропользованию по Республи...
#  65                                   Лацановский И.А.
#  66                                        Гаевая А.В.
#  67                                       Оленица Т.В.
#  68                                        Дуглас О.Г.
#
#                                               position  \
#  1                                                   3
#  2   1. Департамент по недропользованию по Централь...
#  3                                           Начальник
#  4                              Заместитель начальника
#  5                              Заместитель начальника
#  ..                                                ...
#  64  10. Управление по недропользованию по Республи...
#  65                                          Начальник
#  66                             Заместитель начальника
#  67                             Заместитель начальника
#  68                                  Главный бухгалтер
#
#                                                 salary  \
#  1                                                   4
#  2   1. Департамент по недропользованию по Централь...
#  3                                           98 249,50
#  4                                           78 438,83
#  5                                           85 681,65
#  ..                                                ...
#  64  10. Управление по недропользованию по Республи...
#  65                                         131 261,04
#  66                                         109 796,82
#  67                                          62 950,48
#  68                                          86 881,89
#
#                                             department
#  1                                                None
#  2   1. Департамент по недропользованию по Централь...
#  3   1. Департамент по недропользованию по Централь...
#  4   1. Департамент по недропользованию по Централь...
#  5   1. Департамент по недропользованию по Централь...
#  ..                                                ...
#  64  10. Управление по недропользованию по Республи...
#  65  10. Управление по недропользованию по Республи...
#  66  10. Управление по недропользованию по Республи...
#  67  10. Управление по недропользованию по Республи...
#  68  10. Управление по недропользованию по Республи...
#
#  [68 rows x 5 columns],
#                                                   № п/п  \
#  1                                                    1
#  2    1. ФБУ «ТФГИ по Северо-Западному федеральному ...
#  3                                                   1.
#  4                                                   2.
#  5                                                   3.
#  ..                                                 ...
#  133                                                 2.
#  134                                                 3.
#  135                                                 4.
#  136                                                 5.
#  137                                                 6.
#
#                                                    name  \
#  1                                                    2
#  2    1. ФБУ «ТФГИ по Северо-Западному федеральному ...
#  3                                       Русакевич Н.Е.
#  4                                          Ковтун А.Н.
#  5                                         Лукинов В.М.
#  ..                                                 ...
#  133                                        Черных А.И.
#  134                                        Черных А.И.
#  135                                      Вартанян С.С.
#  136                                  Седельникова Г.В.
#  137                                       Суслова Л.Д.
#
#                                                position  \
#  1                                                    3
#  2    1. ФБУ «ТФГИ по Северо-Западному федеральному ...
#  3                                             Директор
#  4                                Заместитель директора
#  5               Заместитель директора – главный геолог
#  ..                                                 ...
#  133               Генеральный директор\n(с 01.12.2018)
#  134  Первый заместитель генерального директора\n(до...
#  135  Заместитель генерального директора\n(уволен с ...
#  136  Заместитель генерального директора\n(уволена с...
#  137                                  Главный бухгалтер
#
#                                                  salary  \
#  1                                                    4
#  2    1. ФБУ «ТФГИ по Северо-Западному федеральному ...
#  3                                           136 752,66
#  4                                            75 676,23
#  5                                            54 127,48
#  ..                                                 ...
#  133                                         311 100,00
#  134                                         490 101,00
#  135                                         227 111,00
#  136                                         310 814,00
#  137                                         344 404,00
#
#                                              department
#  1                                                 None
#  2    1. ФБУ «ТФГИ по Северо-Западному федеральному ...
#  3    1. ФБУ «ТФГИ по Северо-Западному федеральному ...
#  4    1. ФБУ «ТФГИ по Северо-Западному федеральному ...
#  5    1. ФБУ «ТФГИ по Северо-Западному федеральному ...
#  ..                                                 ...
#  133                                  19. ФГБУ «ЦНИГРИ»
#  134                                  19. ФГБУ «ЦНИГРИ»
#  135                                  19. ФГБУ «ЦНИГРИ»
#  136                                  19. ФГБУ «ЦНИГРИ»
#  137                                  19. ФГБУ «ЦНИГРИ»
#
#  [137 rows x 5 columns],
#                         № п/п                      name  \
#  1                          1                         2
#  2   1. ФГУНПП «Аэрогеология»  1. ФГУНПП «Аэрогеология»
#  3                         1.            Самаренко П.В.
#  4                         2.              Иванова О.В.
#  5                         3.           Позднякова Е.П.
#  6                         4.               Карпов Л.К.
#  7    2. ФГУП «ЦНИИгеолнеруд»   2. ФГУП «ЦНИИгеолнеруд»
#  8                         1.              Аксенов Е.М.
#  9                         2.             Васильев Н.Г.
#  10                        3.               Лыгина Т.З.
#  11                        4.              Садыков Р.К.
#  12                        5.             Хайдаров Ш.Х.
#  13                        6.      Фахрутдинова Е.Е.\n
#  14                        7.           Харитонова Е.Н.
#
#                                               position  \
#  1                                                   3
#  2                            1. ФГУНПП «Аэрогеология»
#  3                                Генеральный директор
#  4   Заместитель генерального директора по экономик...
#  5                  Заместитель генерального директора
#  6   Заместитель генерального директора – главный э...
#  7                             2. ФГУП «ЦНИИгеолнеруд»
#  8                                            Директор
#  9                        Первый заместитель директора
#  10                     Заместитель директора по науке
#  11                     Заместитель директора по науке
#  12  Заместитель директора по производственно-хозяй...
#  13          Главных бухгалтер\n(уволена с 11.08.2018)
#  14                  Главных бухгалтер\n(с 01.12.2018)
#
#                        salary                department
#  1                          4                      None
#  2   1. ФГУНПП «Аэрогеология»  1. ФГУНПП «Аэрогеология»
#  3                 218 500,00  1. ФГУНПП «Аэрогеология»
#  4                 180 000,00  1. ФГУНПП «Аэрогеология»
#  5                 180 000,00  1. ФГУНПП «Аэрогеология»
#  6                 180 400,00  1. ФГУНПП «Аэрогеология»
#  7    2. ФГУП «ЦНИИгеолнеруд»   2. ФГУП «ЦНИИгеолнеруд»
#  8                 109 990,00   2. ФГУП «ЦНИИгеолнеруд»
#  9                  67 308,00   2. ФГУП «ЦНИИгеолнеруд»
#  10                 48 754,00   2. ФГУП «ЦНИИгеолнеруд»
#  11                 54 431,00   2. ФГУП «ЦНИИгеолнеруд»
#  12                 48 754,00   2. ФГУП «ЦНИИгеолнеруд»
#  13                 62 037,00   2. ФГУП «ЦНИИгеолнеруд»
#  14                 58 178,00   2. ФГУП «ЦНИИгеолнеруд»  ]

# %%
folder = r'D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\all_docx'
result_folder = r'D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\all_docx\parsed'
errors = []
for file in tqdm_notebook(os.listdir(folder)):
    if file.endswith('.docx'):
        try:
            filepath = folder + '//' + file
            res = parser.parse_file(filepath)
            for i, table in enumerate(res):
                table.to_excel(result_folder + '//' + f'{i}_' + file.strip('.docx')+'.xlsx')    
        except Exception as ex:            
            buffer = io.StringIO()
            traceback.print_exc(file=buffer)
            buffer.seek(0)
            errors.append({'file':file, 'err':buffer.readlines()})
# Out:
# C:\Users\Kirill\AppData\Local\Temp/ipykernel_23064/2268874418.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for file in tqdm_notebook(os.listdir(folder)):
#   0%|          | 0/252 [00:00<?, ?it/s]
# Количество заголовков ---  22
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  10
# Количество таблиц ---  10
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  6
# Количество таблиц ---  6
# Количество заголовков ---  16
# Количество таблиц ---  16
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  3
# Количество таблиц ---  3
# Количество заголовков ---  30
# Количество таблиц ---  30
# C:\Users\Kirill\AppData\Local\Temp/ipykernel_23064/1029505200.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table['department'][0] = 'Учреждение'
# Количество заголовков ---  0
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  39
# Количество таблиц ---  39
# Количество заголовков ---  2
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  0
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  19
# Количество таблиц ---  19
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  3
# Количество таблиц ---  1
# Количество заголовков ---  6
# Количество таблиц ---  6
# Количество заголовков ---  15
# Количество таблиц ---  15
# C:\Users\Kirill\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1724: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer_missing(indexer, value)
#
# C:\Users\Kirill\AppData\Local\Temp/ipykernel_23064/1029505200.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table['department'][0] = 'Учреждение'
# Количество заголовков ---  6
# Количество таблиц ---  6
# Количество заголовков ---  10
# Количество таблиц ---  9
# Количество заголовков ---  35
# Количество таблиц ---  35
# Количество заголовков ---  7
# Количество таблиц ---  7
# Количество заголовков ---  25
# Количество таблиц ---  25
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  3
# Количество таблиц ---  3
# Количество заголовков ---  4
# Количество таблиц ---  4
# Количество заголовков ---  6
# Количество таблиц ---  6
# Количество заголовков ---  16
# Количество таблиц ---  16
# Количество заголовков ---  23
# Количество таблиц ---  40
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  0
# Количество таблиц ---  1
# Количество заголовков ---  2
# Количество таблиц ---  1
# Количество заголовков ---  0
# Количество таблиц ---  1
# Количество заголовков ---  6
# Количество таблиц ---  6
# Количество заголовков ---  5
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  2
# Количество таблиц ---  3
# Количество заголовков ---  3
# Количество таблиц ---  4
# Количество заголовков ---  3
# Количество таблиц ---  4
# Количество заголовков ---  0
# Количество таблиц ---  0
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  2
# Количество таблиц ---  2
# Количество заголовков ---  2
# Количество таблиц ---  2
# Количество заголовков ---  23
# Количество таблиц ---  23
# Количество заголовков ---  25
# Количество таблиц ---  25
# Количество заголовков ---  3
# Количество таблиц ---  3
# Количество заголовков ---  3
# Количество таблиц ---  3
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  0
# Количество таблиц ---  3
# Количество заголовков ---  13
# Количество таблиц ---  13
# Количество заголовков ---  4
# Количество таблиц ---  4
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  0
# Количество таблиц ---  1
# Количество заголовков ---  3
# Количество таблиц ---  3
# Количество заголовков ---  0
# Количество таблиц ---  3
# Количество заголовков ---  30
# Количество таблиц ---  30
# Количество заголовков ---  2
# Количество таблиц ---  2
# Количество заголовков ---  2
# Количество таблиц ---  2
# Количество заголовков ---  3
# Количество таблиц ---  3
# Количество заголовков ---  0
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  25
# Количество таблиц ---  25
# Количество заголовков ---  26
# Количество таблиц ---  26
# Количество заголовков ---  1
# Количество таблиц ---  5
# Количество заголовков ---  1
# Количество таблиц ---  5
# Количество заголовков ---  1
# Количество таблиц ---  6
# Количество заголовков ---  45
# Количество таблиц ---  45
# Количество заголовков ---  2
# Количество таблиц ---  2
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  0
# Количество таблиц ---  1
# Количество заголовков ---  15
# Количество таблиц ---  15
# C:\Users\Kirill\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1724: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer_missing(indexer, value)
#
# C:\Users\Kirill\AppData\Local\Temp/ipykernel_23064/1029505200.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table['department'][0] = 'Учреждение'
# Количество заголовков ---  19
# Количество таблиц ---  19
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  4
# Количество таблиц ---  4
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  3
# Количество таблиц ---  1
# Количество заголовков ---  0
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1
# Количество заголовков ---  1
# Количество таблиц ---  1

# %%
# file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\all_docx\187692_2020_Rukovoditeli_podvedomstvennykh_uchrezhdenii.docx"
# file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\all_docx\187741_2020_Rukovoditeli_podvedomstvennykh_uchrezhdenii_(kul'tura).docx"
# res = parser.par(file)
print(res[0]['Учреждение'].values)
# Out:
# [' приложение  информация о среднемесячной заработной плате за 2020 год   информация о среднемесячной заработной плате за 2020 год   муп «транс-сервис»  '
#  ' приложение  информация о среднемесячной заработной плате за 2020 год   информация о среднемесячной заработной плате за 2020 год   муп «транс-сервис»  ']

# %%
l = [1,2,3]
for e in l:
    e = 1
l
# Out:
# [1, 2, 3]

# %%
errors
# Out:
# 37

# %%
'''
1. Все таблицы
2. У всех ли таблиц есть заголовки
3. Если у некоторых есть, а у других нет и одинаковое кол-во колонок - можно соединить
4. Если нет учреждения:
    а. пытаемся сделать сплит
    б. добавляем весь текст перед таблицей (в классе должен храниться распаршенный вариант)

'''
# я хочу посмотреть у скольких доков не ок заги


#folder = r'D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\all_docx'
# df = res[0].copy()
move_cols_to_rows(df)
# Out:
#                                                 № п/п  \
# 0                                               № п/п
# 1                                                   2
# 2                                                   1
# 3   1. Департамент по недропользованию по Централь...
# 4                                                  1.
# ..                                                ...
# 65  10. Управление по недропользованию по Республи...
# 66                                                 1.
# 67                                                 2.
# 68                                                 3.
# 69                                                 4.
#
#                                Фамилия, имя, отчество  \
# 0                              Фамилия, имя, отчество
# 1                                                   3
# 2                                                   2
# 3   1. Департамент по недропользованию по Централь...
# 4                                       Савицкий М.Ф.
# ..                                                ...
# 65  10. Управление по недропользованию по Республи...
# 66                                   Лацановский И.А.
# 67                                        Гаевая А.В.
# 68                                       Оленица Т.В.
# 69                                        Дуглас О.Г.
#
#                                             Должность  \
# 0                                           Должность
# 1                                                   4
# 2                                                   3
# 3   1. Департамент по недропользованию по Централь...
# 4                                           Начальник
# ..                                                ...
# 65  10. Управление по недропользованию по Республи...
# 66                                          Начальник
# 67                             Заместитель начальника
# 68                             Заместитель начальника
# 69                                  Главный бухгалтер
#
#              Среднемесячная заработная плата,\nрублей
# 0            Среднемесячная заработная плата,\nрублей
# 1                                              aaaaaa
# 2                                                   4
# 3   1. Департамент по недропользованию по Централь...
# 4                                           98 249,50
# ..                                                ...
# 65  10. Управление по недропользованию по Республи...
# 66                                         131 261,04
# 67                                         109 796,82
# 68                                          62 950,48
# 69                                          86 881,89
#
# [70 rows x 4 columns]
