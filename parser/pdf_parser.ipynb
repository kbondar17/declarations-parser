# %%
import logging
from tqdm import tqdm_notebook
from pathlib import Path
import requests
import re
import time
import os
import urllib.request
from typing import Union
import csv
import statistics

import typing
import io
import numpy as np
from docx import Document


import camelot

import pandas as pd
logging.basicConfig(format=u'%(filename)+13s [ LINE:%(lineno)-4s] %(levelname)-8s %(message)s',
                    level=logging.DEBUG)

logger = logging.getLogger(__name__)


class PdfParser:

    @staticmethod
    def convert_pdf_to_df(filename) -> list[pd.DataFrame]:
        tables = camelot.read_pdf(filename, line_tol=2, joint_tol=10, line_scale=40, copy_text=[
                                  'v'], pages='1-end')  # , flavor='stream' row_tol=10
        tables = [e.df for e in tables]
        return tables


base = '../data_ids/pdf/converted/'
file = '../data_ids/pdf/converted/189273_2020_Rektor,_prorektory,_glavnyi_bukhgalter.pdf'
file = "D:/PROGR/LEARN_PYTHON/Declarator/declarations-parser/data_ids/pdf/converted/189273_2020_Rektor,_prorektory,_glavnyi_bukhgalter.pdf"


def convert_pdf_to_df(file) -> list[pd.DataFrame]:
    tables = camelot.read_pdf(file, line_tol=2, joint_tol=10, line_scale=40, copy_text=[
                              'v', 'h'], pages='1-end')  # , flavor='stream' row_tol=10
    tables = [e.df for e in tables]
    return tables


file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\pdf\converted\83326_2017_Rukovoditeli,_zamestiteli_i_glavnye_bukhgaltery_podvedomstvennykh_uchrezhdenii.pdf"

res = convert_pdf_to_df(file)
res

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11960/1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\res.xlsx"
df = pd.read_excel(file)

df
# Out:
#     Unnamed: 0                                 name  \
# 0            0               Зубов Юрий \nСергеевич
# 1            1          Гаврилова Елена \nБорисовна
# 2            2  Горбунов \nАлександр \nВладимирович
# 3            3   Прищеп \nАлександр \nАлександрович
# 4            4  Суконкин \nАлександр \nВладимирович
# 5            5            Бурдина Елена \nБорисовна
# 6            6           Близнец Иван \nАнатольевич
# 7            7          Смирнова \nВероника Ремовна
# 8            8     Вилинов \nАлександр \nМихайлович
# 9            9            Быкова Ольга \nНиколаевна
# 10          10         Гриднева Евгения \nСергеевна
# 11          11     Новиков \nАлександр \nНиколаевич
# 12          12        Романов Алексей \nГеннадьевич
# 13          13    Рыбалкин \nВладимир \nГеннадьевич
# 14          14           Рукин Олег \nАлександрович
# 15          15            Маркова Ирина \nБорисовна
#
#                                            department      salary  \
# 0   Федеральное государственное бюджетное учрежден...  381 053,00
# 1   Федеральное государственное бюджетное учрежден...  224 305,00
# 2   Федеральное государственное бюджетное учрежден...  249 159,00
# 3   Федеральное государственное бюджетное учрежден...  294 636,00
# 4   Федеральное государственное бюджетное учрежден...  305 107,00
# 5   Федеральное государственное бюджетное учрежден...  244 509,00
# 6   Федеральное государственное бюджетное образова...  276 891,08
# 7   Федеральное государственное бюджетное образова...  157 515,02
# 8   Федеральное государственное бюджетное образова...  111 924,98
# 9   Федеральное государственное бюджетное образова...  137 583,00
# 10  Федеральное государственное бюджетное образова...   86 627,38
# 11  Федеральное государственное бюджетное учрежден...  197 812,00
# 12  Федеральное государственное бюджетное учрежден...  184 153,00
# 13  Федеральное государственное бюджетное учрежден...  184 231,00
# 14  Федеральное государственное бюджетное учрежден...   90 675,00
# 15  Федеральное государственное бюджетное учрежден...  177 429,00
#
#                                              position documentfile_id
# 0                                            Директор      83334_2018
# 1                               Заместитель директора      83334_2018
# 2                               Заместитель директора      83334_2018
# 3                               Заместитель директора      83334_2018
# 4                               Заместитель директора      83334_2018
# 5                                   Главный бухгалтер      83334_2018
# 6                                              Ректор      83334_2018
# 7   Проректор по научной \nработе и международному...      83334_2018
# 8   Проректор по \nинновационной \nдеятельности и ...      83334_2018
# 9   Проректор по учебно-\nметодической и \nвоспита...      83334_2018
# 10  Начальник Финансово \nадминистративного \nупра...      83334_2018
# 11                                           Директор      83334_2018
# 12                              Заместитель директора      83334_2018
# 13                              Заместитель директора      83334_2018
# 14                              Заместитель директора      83334_2018
# 15                                  Главный бухгалтер      83334_2018
