# %%
"""ПАРСИМ ТЕКСТ ИЗ ПДФ.
Задача - вытащить текст и инфу о таблицах.

1. PDFMiner
2. PyPDF2
3. pdfrw

"""

# %%
file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\pdf\converted\188456_2020_Rukovoditeli_podvedomstvennykh_uchrezhdenii_(obrazovanie).pdf"
file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\pdf\converted\189429_2020_Rektor,_prorektory,_glavnyi_bukhgalter.pdf"
file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\pdf\converted\179171_2020_Rukovoditeli,_zamestiteli_i_glavnye_bukhgaltery_podvedomstvennykh_uchrezhdenii.pdf"

# text = pdfminer.high_level.extract_text(file)
# text

import pdfminer
text = pdfminer.high_level.extract_text(file)
# repr(text)
from io import StringIO
from pdfminer.layout import LAParams
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

output_string = StringIO()
with open(file, 'rb') as in_file:
    parser = PDFParser(in_file)
    doc = PDFDocument(parser)
    rsrcmgr = PDFResourceManager()
    device = TextConverter(rsrcmgr, output_string, laparams=LAParams(char_margin=1))
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    for page in PDFPage.create_pages(doc):
        interpreter.process_page(page)

print(output_string.getvalue())
# Out:
# Информация
# о среднемесячной заработной плате
# руководителя (заместителя руководителя, главного бухгалтера)
#
# Государственное бюджетное учреждение
#  Липецкой области
# «Центр спортивной подготовки»
# (наименование организации)
#
# за 2020 год
#
# Должность
#
# Ф.И.О.
#
# Зюзин Александр
# Викторович
# Севостьянова Елена
# Юрьевна
# Куприянова Татьяна
# Алексеевна
# Словцова Лариса Петровна
#
#
# директор
#
# заместитель директора
#
# заместитель директора
#
# главный бухгалтер
#
# Среднемесячная
# заработная плата, руб.
# 76242
#
# 67104
#
# 55537
#
# 53004
#
# ИНФОРМАЦИЯ
# о среднемесячной заработной плате
# руководителя (заместителя руководителя, главного бухгалтера)
# Государственное бюджетное учреждение Липецкой области
# Спортивная школа олимпийского резерва имени Александра
# Митрофановича Никулина
# (наименование организации)
# за 20 20  год
#
# ФИО
#
# Должность
#
# Среднемесячная
# заработная плата, руб.
#
# директор
#
# 81 548,88
#
#
#
# Никулин Игорь
# Александрович
# ...

# %%
folder = r'D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\pdf\converted\для которых нужен перевод в ворд'

file = r"D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\pdf\converted\для которых нужен перевод в ворд\89058_2019_Rukovoditeli,_zamestiteli_i_glavnye_bukhgaltery_podvedomstvennykh_uchrezhdenii.pdf"

import pdf2docx
from pathlib import Path

#pdf_file = '/path/to/sample.pdf'

#cv = Converter(file)
import io
import os
folder = r'D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\pdf\converted\для которых нужен перевод в ворд'
folder_path = Path(folder)

for e in os.listdir(folder):
    if e.endswith('.pdf'):
        orig_file_name = e.strip('.pdf')
        new_name = orig_file_name + '.docx'        
        pdf2docx.parse(folder_path / e, folder_path / new_name)


# temp_doc = 'temp_doc.docx'
# pdf2docx.parse(file, temp_doc)



#cv.parse_document()

# res = cv.parse_pages()
# print(dir(cv))

# res.parse()
# cv.parse()
# tables = cv.extract_tables(start=0, end=1)
# cv.close()

# for table in tables:
#     print(table)


# чекнуть хедерс. если ок - парсим
# Out:
# [INFO] Start to convert D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\pdf\converted\для которых нужен перевод в ворд/88766_2019_Rukovoditeli,_zamestiteli_i_glavnye_bukhgaltery_podvedomstvennykh_uchrezhdenii.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/1) Page 1
# [INFO] [4/4] Creating pages...
# [INFO] (1/1) Page 1
# [INFO] Terminated in 0.33s.
# [INFO] Start to convert D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\pdf\converted\для которых нужен перевод в ворд/88767_2018_Rukovoditeli,_zamestiteli_i_glavnye_bukhgaltery_podvedomstvennykh_uchrezhdenii.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/1) Page 1
# [INFO] [4/4] Creating pages...
# [INFO] (1/1) Page 1
# [INFO] Terminated in 0.62s.
# ...

# %%
import fitz

doc = fitz.open(file)


for e in range(doc.page_count):
    page = doc.load_page(e)

    text = page.get_text('dict')
    print(text)
    print('==')

# %%
def if_not_pdf_with_headers(filename: str):
    # переводим пфд в ворд
    orig_file_name = e.strip('.pdf')
    new_name = 'temp_to_delete' + orig_file_name + '.docx'        
    pdf2docx.parse(e, new_name)
    return new_name


# import pdf2docx
# from pathlib import Path

# #pdf_file = '/path/to/sample.pdf'

# #cv = Converter(file)
# import io
# import os
# folder = r'D:\PROGR\LEARN_PYTHON\Declarator\declarations-parser\data_ids\pdf\converted\для которых нужен перевод в ворд'
# folder_path = Path(folder)

# for e in os.listdir(folder):
#     if e.endswith('.pdf'):
#         orig_file_name = e.strip('.pdf')
#         new_name = orig_file_name + '.docx'        
#         pdf2docx.parse(folder_path / e, folder_path / new_name)





# если нет - перегоняем в ворд и вытаскиваем описание вокруг. 
# все давай закругляться.
